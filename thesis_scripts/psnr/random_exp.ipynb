# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import math
from PIL import Image
#import cPickle as pkl
import _pickle as cPickle
import time
import tensorflow as tf
import tensorflow.examples.tutorials.mnist.input_data as input_data
import glob
# %matplotlib inline

# %%
dirpath = "/home/saurabh/Documents/data/iccv09Data/images/"

# %%
fileList = glob.glob(dirpath + '*.jpg')

for i, file in enumerate(fileList):
    img = Image.open(file)
    array = np.array(img)
    
    print(i,file)
# Out:
# 0 /home/saurabh/Documents/data/iccv09Data/images/17821118_10212469376230355_776888092_n.jpg
# 1 /home/saurabh/Documents/data/iccv09Data/images/0000047.jpg
# 2 /home/saurabh/Documents/data/iccv09Data/images/17793248_10212469376150353_1451974312_n.jpg
# 3 /home/saurabh/Documents/data/iccv09Data/images/0000631.jpg
# 4 /home/saurabh/Documents/data/iccv09Data/images/0000176.jpg
# 5 /home/saurabh/Documents/data/iccv09Data/images/0000382.jpg
# 6 /home/saurabh/Documents/data/iccv09Data/images/17506262_10212469376190354_226964340_n.jpg
# 7 /home/saurabh/Documents/data/iccv09Data/images/17814127_10212469376110352_2109687650_n.jpg
# 8 /home/saurabh/Documents/data/iccv09Data/images/17807106_10212469376270356_1904211455_n.jpg
# 9 /home/saurabh/Documents/data/iccv09Data/images/0000072.jpg
# 10 /home/saurabh/Documents/data/iccv09Data/images/0000059.jpg
# 11 /home/saurabh/Documents/data/iccv09Data/images/0000051.jpg
# 12 /home/saurabh/Documents/data/iccv09Data/images/0000643.jpg
# ...

# %%
file1 = "/home/saurabh/Documents/data/iccv09Data/1001875.jpg"

# %%
img = Image.open(file1)

# %%
array = np.array(img)

# %%
array.shape

if array.shape[0] == 240 and array.shape[1] == 360:
    print("......")

# %%
array.shape
# Out:
# (240, 320, 3)

# %%
plt.imshow(array[110:370,110:250,:], interpolation="none")

# %%
rgb = array.reshape(1,240,360,3)

# %%
rgb.shape
# Out:
# (1, 240, 360, 3)

# %%
imglow = img.resize((int(width/resize_ratio),int(height/resize_ratio)), Image.BICUBIC)

# %%
width = 360
height = 240
resize_ratio = 4

# %%
imglow = img.resize((int(width/resize_ratio), int(height/resize_ratio)), Image.BICUBIC)

# %%
plt.imshow(imglow)
#plt.imshow(array)

# %%
plt.imshow(array)

# %%
imglow.height
img.height
# Out:
# 240

# %%
imglow = imglow.resize((width, height), Image.BILINEAR)

# %%
imglow.height
# Out:
# 240

# %%
rgb.dtype
# Out:
# dtype('uint8')

# %%
rgb.shape
# Out:
# (1, 240, 360, 3)

# %%
rgblow = np.array(np.float32(imglow)/255)

# %%
rgblow = np.array(np.float32(imglow))

# %%
rgblow = rgblow.reshape(1, height, width, 3)

# %%
rgblow.shape
# Out:
# (1, 240, 360, 3)

# %%
rgb = np.reshape(rgb, [1, -1])

# %%
rgb
# Out:
# array([[122, 122, 122, ...,  68, 142,  65]], dtype=uint8)

# %%
rgblow = np.reshape(rgblow, [1, -1])

# %%
rgblow
# Out:
# array([[ 34.,  34.,  34., ...,  18.,  96.,  17.]], dtype=float32)

# %%
data = rgb
datalow = rgblow

# %%
data
# Out:
# array([[122, 122, 122, ...,  68, 142,  65]], dtype=uint8)

# %%
datalow
# Out:
# array([[ 34.,  34.,  34., ...,  18.,  96.,  17.]], dtype=float32)

# %%
data.shape
# Out:
# (1, 259200)

# %%
datalow = datalow *100

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-129-9084040900ed> in <module>()
# ----> 1 datalow.shape = datalow[1*100, 259200*100]
#
# IndexError: index 100 is out of bounds for axis 0 with size 1

# %%
data*data - datalow*datalow
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-130-21101ed8b7c4> in <module>()
# ----> 1 data*data - datalow*datalow
#
# ValueError: operands could not be broadcast together with shapes (1,240,360,3) (1,259200)

# %%
x =  data - datalow

# %%
# Out:
# array([[ 88.,  88.,  88., ...,  50.,  46.,  48.]], dtype=float32)

# %%
x = x.reshape(-1, height, width, 3)
x
# Out:
# array([[[[ 88.,  88.,  88.],
#          [-10., -10., -10.],
#          [-22., -22., -22.],
#          ...,
#          [-18., -18., -18.],
#          [ -6.,  -7.,  -6.],
#          [ 63.,  60.,  61.]],
#
#         [[ 88.,  88.,  88.],
#          [-10., -10., -10.],
#          [-22., -22., -22.],
#          ...,
#          [-18., -18., -18.],
#          [ -6.,  -7.,  -6.],
#          [ 63.,  60.,  61.]],
#
#         [[ 88.,  88.,  88.],
#          [-10., -10., -10.],
#          [-22., -22., -22.],
#          ...,
#          [-18., -18., -18.],
#          [ -6.,  -7.,  -6.],
#          [ 63.,  60.,  61.]],
#
#         ...,
#         [[ 34.,  28.,  31.],
#          [ -2.,  -8.,  -5.],
#          [ -4., -10.,  -9.],
#          ...,
#          [-15., -15., -15.],
#          [ -4.,  -5.,  -4.],
#          [ 51.,  47.,  49.]],
#
#         [[ 26.,  34.,  31.],
#          [ -6.,   2.,  -1.],
#          [ -4.,   4.,   1.],
#          ...,
#          [-14., -16., -16.],
# ...

# %%
imshow(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-119-cc354a326c94> in <module>()
# ----> 1 imshow(x)
#
# NameError: name 'imshow' is not defined

# %%
plt.data(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-113-96c952b6c8b3> in <module>()
# ----> 1 plt.data(x)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'data'

# %%
randidx = np.random.permutation(100)

# %%
randidx
# Out:
# array([87, 80, 38, 58, 20, 70, 41, 78, 92, 67,  9, 68, 76, 11, 22, 42, 60,
#        98, 62, 59,  2, 33,  7, 37,  5,  1, 85, 74, 50, 89,  3, 32, 31, 64,
#        10, 95, 99, 28, 73, 40, 46, 61, 19, 71, 72, 97, 36, 24, 12, 44, 43,
#        88, 30, 47, 93,  4, 45, 21, 82, 52, 25, 48, 91, 16, 63, 84,  6, 77,
#        27, 86, 66,  0, 14, 57, 54, 55, 56, 13, 53,  8, 17, 49, 96, 29, 65,
#        69, 75, 81, 90, 79, 83, 51, 34, 18, 15, 23, 94, 26, 39, 35])

# %%
nrtrain = int(0.7 * 100)

# %%
nrtrain
# Out:
# 70

# %%
nrtest = 100 - nrtrain

# %%
nrtest
# Out:
# 30

# %%
M.S.E  [ tf.reshape(_X, shape=[-1, height, width, 3])   -  tf.reshape(y, shape=[-1, height, width, 3])  ]

# %%
np.reshape(recon[example_i, :], (height, width, 3))

# %%
yy = randidx[2,:]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-131-e2986a043147> in <module>()
# ----> 1 yy = randidx[2,:]
#
# IndexError: too many indices for array

# %%
np.reshape(recon[example_i, :], (height, width, 3)))
# Out:
#   File "<ipython-input-1-5d36c658fc4d>", line 1
#     np.reshape(recon[example_i, :], (height, width, 3)))
#                                                        ^
# SyntaxError: invalid syntax

# %%
from PIL import Image
import os, sys

path = "/home/saurabh/Documents/data/iccv09Data/images/"
dirs = os.listdir( path )

def resize():
    for item in dirs:
        if os.path.isfile(path+item):
            im = Image.open(path+item)
            f, e = os.path.splitext(path+item)
            imResize = im.resize((360,240), Image.ANTIALIAS)
            imResize.save(f + ' resized.jpg', 'JPEG', quality=90)

resize()

# %%
a = data = rgb
datalow = rgblow
In [104]:
￼
data
Out[104]:
array([[122, 122, 122, ...,  68, 142,  65]], dtype=uint8)
In [105]:
￼
datalow
Out[105]:
array([[ 34.,  34.,  34., ...,  18.,  96.,  17.]], dtype=float32)
In [106]:
￼
data.shape
Out[106]:
(1, 259200)
In [126]:
￼
datalow = datalow *100
In [129]:
￼
​
---------------------------------------------------------------------------
IndexError                                Traceback (most recent call last)
<ipython-input-129-9084040900ed> in <module>()
----> 1 datalow.shape = datalow[1*100, 259200*100]

IndexError: index 100 is out of bounds for axis 0 with size 1

In [130]:
￼
data*data - datalow*datalow
---------------------------------------------------------------------------
ValueError                                Traceback (most recent call last)
<ipython-input-130-21101ed8b7c4> in <module>()
----> 1 data*data - datalow*datalow

ValueError: operands could not be broadcast together with shapes (1,240,360,3) (1,259200)

# %%
a = [2820.3447, 897.58453, 813.8219, 1293.4331, 1026.2576, 1102.7046, 2059.0266, 407.05035, 939.13116, 780.92395, 520.65125, 665.41321, 459.20636, 385.41537, 553.65051, 305.94415, 397.43106, 374.37308, 406.28342, 575.34827, 496.10101, 430.15952, 615.03986, 283.98856, 526.39825, 407.26736, 524.96136, 447.09146, 429.32385, 207.70474, 297.77856, 550.23895, 512.45276, 467.37305, 468.21161, 812.66193, 895.49249, 655.04932, 413.0191, 342.36517, 564.93561, 436.56921, 420.64883, 404.38287, 493.87924, 572.60968, 416.36807, 555.67297, 442.45963, 216.02924, 514.01672, 440.70822, 412.50165, 360.22198, 474.78729, 373.68277, 481.25769, 466.29617, 688.99579, 560.66772, 435.99182, 322.42245, 359.57071, 733.86243, 560.05743, 415.95273, 466.11823, 394.48862, 548.57031, 329.38043, 430.9176, 386.82007, 516.15106, 908.87048, 565.86523, 372.93964, 417.582, 538.82153, 599.91351, 455.29156, 621.02332, 567.97131, 455.78934, 460.48511, 359.90912, 736.51416, 592.11755, 586.59528, 608.97919, 593.65869, 403.78766, 499.07608, 581.06702, 625.85028, 692.33563, 507.52222, 278.64337, 547.90326, 235.93437, 406.12659, 749.65094, 524.43359, 463.38446, 462.40607, 508.07196, 784.04089, 726.48688, 509.4137, 385.66919, 397.02673, 731.96564, 693.2887, 580.04675, 425.31851, 333.50821, 677.0282, 566.66553, 508.13867, 500.95819, 440.6409, 691.79285, 370.40317, 299.15952, 512.79047, 615.9928, 486.44952, 321.35065, 523.85406, 238.60071, 642.96472, 674.7688, 330.75082, 373.17865, 545.33643, 682.61365, 583.22046, 514.75958, 445.86844, 511.67041, 391.44806, 431.35959, 572.80804, 735.03229, 218.9054, 714.57306, 197.28302, 362.14496, 439.15195, 400.71255, 388.37918, 557.41144, 720.15692, 398.04883, 446.31998, 483.94662, 841.59131, 444.866, 650.49872, 429.90076, 515.40063, 283.26562, 433.45221, 409.38324, 378.64288, 622.23749, 737.00354, 447.72861, 503.69083, 602.70319, 498.13388, 388.39972, 436.67001, 404.92587, 627.96375, 660.66309, 502.41656, 500.09592, 262.70966, 510.763, 585.63702, 427.76715, 562.75293, 365.03925, 822.95856, 732.90283, 437.70276, 434.7644, 389.62491, 336.94699, 731.55902, 496.17078, 567.03119, 449.74518, 475.21124, 529.18811, 586.99841, 377.54465, 300.70874, 420.51016, 388.20187, 362.26889, 540.65247, 964.51727, 532.27106, 418.29468, 456.03952, 559.96851, 476.59244, 463.50153, 393.50412, 258.63712, 407.22568, 352.41446, 596.36267, 586.323, 479.87982, 311.24106, 679.21783, 594.73114, 466.00522, 514.85748, 711.74939, 647.64642, 620.72339, 385.08051, 857.0011, 482.31012, 439.6142, 536.35492, 431.30743, 726.80432, 414.35199, 630.6297, 517.38208, 407.41833, 423.8129, 427.1904, 306.75262, 413.27527, 616.67041, 380.39737, 981.6106, 377.02612, 439.45905, 663.51715, 472.77542, 309.48505, 340.73886, 412.7612, 436.86536, 760.49786, 634.05322, 626.84534, 779.9137, 586.11877, 344.59213, 653.02802, 462.59406, 372.29816, 332.88779, 260.17691, 826.42395, 458.4939, 474.95135, 620.15961, 424.48288, 454.04556, 294.37216, 697.39423, 517.40283, 586.53992, 433.70123, 340.6749, 452.16351, 495.95172, 531.23132, 369.08447, 386.91193, 777.9046, 389.46902, 467.25912, 493.86313, 390.22495, 471.97983, 891.25079, 208.71909, 587.83844, 539.01025, 468.69977, 700.06097, 645.03638, 449.91772, 388.0976, 423.6745, 509.27408, 505.9595, 373.96118, 575.53455, 972.29059, 425.10635, 354.04678, 439.716, 624.66187, 597.66168, 484.43433, 455.22665, 515.50769, 788.49731, 467.46194, 557.86115, 266.49899, 730.51685, 737.99475, 598.02087, 671.53314, 784.0564, 662.1322, 460.27811, 400.99741, 524.17456, 451.91995, 715.4762, 729.48071, 562.65314, 391.3768, 409.44348, 428.62683, 785.10223, 606.30579, 662.75031, 327.34741, 287.39459, 395.33279, 531.63171, 367.39545, 785.83325, 518.54242, 535.89722, 389.32425, 562.90729, 443.91919, 510.42725, 686.44232, 348.71442, 393.09845, 646.26245, 465.96222, 229.75813, 495.69635, 207.28531, 387.1062, 637.41705, 338.07327, 269.31985, 548.79431, 379.33838, 553.21967, 501.99057, 724.3147, 579.27484, 511.612, 439.79404, 722.59735, 506.74869, 509.41779, 465.69769, 352.63937, 464.84851, 346.61063, 559.50793, 383.58624, 817.23981, 403.29431, 509.17221, 641.24341, 395.90924, 753.74481, 605.43896, 281.2374, 501.23932, 436.83508, 316.76254, 477.13724, 743.27216, 422.59113, 460.29272, 317.69806, 843.38422, 347.90887, 704.64124, 549.06427, 949.33862, 233.26593, 547.69568, 622.81726, 496.61295, 580.10242, 333.65253, 720.21448, 470.06094, 453.70337, 372.99017, 522.2262, 489.6748, 775.10815, 529.7915, 351.94656, 640.84167, 570.22504, 296.78912, 792.41083, 287.1163, 435.79434, 446.10736, 723.57013, 348.62433, 454.62802, 316.26581, 635.94055, 593.15771, 469.05539, 478.5412, 439.84076, 538.2384, 599.7547, 458.46713, 457.47208, 624.16138, 459.99475, 799.38422, 274.07556, 379.13873, 502.27133, 470.95764, 602.7345, 569.66272, 419.23749, 276.20956, 437.9313, 317.38663, 888.14972, 439.5831, 383.80936, 415.69617, 479.05292, 300.84674, 744.29926, 445.74332, 429.50729, 543.90295, 564.9967, 669.65588, 323.08429, 691.9104, 673.50751, 573.21375, 249.82819, 628.32452, 423.97101, 412.89841, 650.84814, 376.30286, 737.51929, 442.6127, 567.55438, 902.40619, 426.65683, 231.17673, 453.32535, 426.60757, 592.72528, 591.35809, 597.73993, 687.09619, 675.91437, 396.96536, 447.55145, 476.7948, 828.34399, 396.05054, 438.70761, 818.06586, 513.96741, 369.75198]

# %%
plt.plot(a)
plt.grid(True)
plt.show()

# %%
print(len(a))
# Out:
# 484

# %%
ar = np.reshape(array, 240*320*3 )

# %%
print(ar)
# Out:
# [138 109 101 ...,  77  88 110]

# %%
array2 = array

# %%
array2[110:113,45:55,] = array2[2,2,:]

# %%
imglow = array2.resize((90,60, Image.BICUBIC))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-1d123ee7d9e7> in <module>()
# ----> 1 imglow = array2.resize((90,60, Image.BICUBIC))
#
# ValueError: cannot resize an array that references or is referenced
# by another array in this way.  Use the resize function

# %% [raw]
# res = array - array2

# %% [raw]
# lr = "/home/saurabh/Desktop/demo/7/LR.jpg"
# lrimg = Image.open(lr)
# lrarray = np.array(lrimg)

# %%
t = [[[1, 1, 1],[2, 2, 2]],[[3, 3, 3],[4, 4, 4]], [[5, 5, 5],[6, 6, 6]]]

# %%
hr = "/home/saurabh/Desktop/demo/7/HR.jpg"
hrimg = Image.open(hr)
hrarray = np.array(hrimg)

# %%
sr = "/home/saurabh/Desktop/demo/7/SR.jpg"
srimg = Image.open(sr)
srarray = np.array(srimg)

# %%
err_2420 = [1496.2167, 1070.6731, 579.06116, 1337.0227, 1068.35, 493.32864, 591.97125, 941.37006, 751.69476, 523.96454, 539.30084, 784.39758, 468.75769, 641.45569, 488.26688, 807.16931, 820.93964, 698.00818, 647.15118, 633.97736, 345.73544, 584.94751, 813.1709, 636.93646, 951.92682, 1018.826, 653.44055, 390.34988, 446.75616, 619.32959, 321.11243, 525.02185, 561.70148, 292.21158, 429.18555, 393.15619, 493.83105, 392.33035, 562.2251, 328.27756, 515.89496, 245.27271, 529.05878, 429.24161, 463.11792, 562.2821, 654.81427, 652.50934, 532.49731, 214.56815, 946.49573, 262.28311, 315.51132, 503.61316, 483.46072, 575.24054, 546.08203, 359.77942, 981.4917, 425.22015, 524.95148, 262.69809, 454.5426, 373.47458, 428.35837, 580.50153, 324.92719, 317.452, 388.0567, 340.44397, 662.30615, 578.38239, 243.83844, 357.71719, 465.47409, 288.9101, 663.88544, 502.63324, 409.85736, 361.17728, 410.23523, 524.12994, 572.65997, 335.72079, 395.36475, 323.00629, 507.58221, 697.65143, 326.72614, 217.7684, 343.59714, 406.3226, 549.18567, 480.86276, 272.71188, 470.89334, 489.0289, 351.29272, 517.59155, 390.33746, 457.88504, 300.32831, 350.11481, 239.67986, 522.91052, 441.00171, 332.19223, 421.75793, 545.67096, 405.58563, 423.55344, 400.97461, 487.27939, 261.5018, 537.27887, 255.25565, 539.19281, 439.21185, 351.01071, 226.19919, 454.58871, 460.45898, 217.68483, 519.16089, 564.96393, 367.10959, 362.85104, 951.62653, 430.52567, 312.0976, 351.26624, 573.01453, 853.92291, 283.04111, 364.23203, 607.14917, 393.22833, 262.93268, 735.28693, 348.61365, 468.14255, 506.25415, 627.40375, 490.03217, 388.95734, 463.19019, 301.08899, 314.9967, 329.27896, 305.62134, 378.24097, 626.40753, 484.93732, 706.41608, 401.85223, 535.18469, 450.20459, 560.8559, 416.6163, 588.40411, 404.48135, 658.34381, 518.16431, 438.92346, 212.39336, 145.27347, 442.67841, 525.67438, 446.60953, 249.08133, 349.91537, 325.9747, 432.9563, 562.53485, 356.28329, 610.71191, 188.52821, 679.50055, 785.8476, 263.8595, 347.44577, 368.71066, 381.76743, 569.04663, 229.18507, 344.77243, 447.15933, 405.15137, 805.10101, 420.81851, 316.97504, 350.0744, 645.92822, 285.38055, 588.10297, 290.5332, 528.18652, 545.1496, 495.7764, 193.7872, 290.17377, 534.66718, 503.38025, 550.33844, 298.38022, 429.60583, 286.2139, 201.1981, 539.63385, 664.01508, 549.1283, 901.38068, 282.13055, 476.23587, 455.38809, 442.58218, 480.53232, 495.96594, 782.25946, 424.00092, 314.63074, 451.70441, 454.4809, 602.65826, 507.97787, 484.32355, 319.78311, 381.80579, 517.30676, 480.31796, 343.61514, 408.08981, 497.19824, 552.0636, 406.02966, 724.31659, 496.6825, 389.30692, 482.60382, 547.17328, 334.67444, 196.7047, 385.66312]

# %%
blah = hrimg.resize((120,120))

# %%
def PSNRLoss(y_true, y_pred):
    """
    PSNR is Peek Signal to Noise Ratio, which is similar to mean squared error.
    It can be calculated as
    PSNR = 20 * log10(MAXp) - 10 * log10(MSE)
    When providing an unscaled input, MAXp = 255. Therefore 20 * log10(255)== 48.1308036087.
    However, since we are scaling our input, MAXp = 1. Therefore 20 * log10(1) = 0.
    Thus we remove that component completely and only compute the remaining MSE component.
    """
    return -10. * np.log10(K.mean(K.square(y_pred - y_true)))

def psnr(y_true, y_pred):
    assert y_true.shape == y_pred.shape, "Cannot calculate PSNR. Input shapes not same." \
                                         " y_true shape = %s, y_pred shape = %s" % (str(y_true.shape),
                                                                                   str(y_pred.shape))

    return 20. * np.log10(255) -10. * np.log10(np.mean(np.square(y_pred - y_true)))

# %%
psnr(hrarray,srarray)
# Out:
# 28.752827898441815

# %%
psnr(hrarray,lrarray)
# Out:
# 29.886322536199398

# %%
import matplotlib.pyplot as plt
from PIL import Image
import os, sys
import numpy as np
import math
from PIL import Image
#import cPickle as pkl
#import _pickle as cPickle
import time
import tensorflow as tf
import tensorflow.examples.tutorials.mnist.input_data as input_data
import glob
from scipy.misc import imsave
#%matplotlib inline  
print ("Packages loaded")
# Out:
# Packages loaded

# %%
path = "/home/saurabh/Documents/data/iccv09Data/"
dirs = os.listdir( path )

def resize():
    for item in dirs:
        if os.path.isfile(path+item):
            im = Image.open(path+item)
            f, e = os.path.splitext(path+item)
            imResize = im.resize((120,120), Image.ANTIALIAS)
            imResize.save(f + '.jpg', 'JPEG', quality=90)
    print("Done")

resize()
# Out:
# Done
