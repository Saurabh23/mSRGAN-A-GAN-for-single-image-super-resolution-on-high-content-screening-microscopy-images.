# %%
from scipy.misc import imread, imresize, imsave
import matplotlib.pyplot as plt
import skimage.io
import skimage.transform
import numpy as np
from skimage import io
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-8ebfb689793f> in <module>()
#       1 from scipy.misc import imread, imresize, imsave
#       2 import matplotlib.pyplot as plt
# ----> 3 import skimage.io
#       4 import skimage.transform
#       5 import numpy as np
#
# ImportError: No module named 'skimage'

# %%
im1 = imread("/home/saurabh/Documents/dogscats/sample/train/cats/cat.394.jpg")
img = io.imread('/home/saurabh/Documents/dogscats/sample/train/cats/cat.394.jpg', as_grey=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-70e074190b72> in <module>()
# ----> 1 im1 = imread("/home/saurabh/Documents/dogscats/sample/train/cats/cat.394.jpg")
#       2 img = io.imread('/home/saurabh/Documents/dogscats/sample/train/cats/cat.394.jpg', as_grey=True)
#
# C:\Users\Saurabh\Anaconda3\envs\tf35\lib\site-packages\scipy\misc\pilutil.py in imread(name, flatten, mode)
#     154     """
#     155
# --> 156     im = Image.open(name)
#     157     return fromimage(im, flatten=flatten, mode=mode)
#     158
#
# C:\Users\Saurabh\Anaconda3\envs\tf35\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2310
#    2311     if filename:
# -> 2312         fp = builtins.open(filename, "rb")
#    2313
#    2314     try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/saurabh/Documents/dogscats/sample/train/cats/cat.394.jpg'

# %%
p1 = imread("/home/saurabh/Documents/dogscats/mitonui/1_H9_1_red.tif")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-ca0f33ec3e3a> in <module>()
# ----> 1 p1 = imread("/home/saurabh/Documents/dogscats/mitonui/1_H9_1_red.tif")
#
# C:\Users\Saurabh\Anaconda3\envs\tf35\lib\site-packages\scipy\misc\pilutil.py in imread(name, flatten, mode)
#     154     """
#     155
# --> 156     im = Image.open(name)
#     157     return fromimage(im, flatten=flatten, mode=mode)
#     158
#
# C:\Users\Saurabh\Anaconda3\envs\tf35\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2310
#    2311     if filename:
# -> 2312         fp = builtins.open(filename, "rb")
#    2313
#    2314     try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/saurabh/Documents/dogscats/mitonui/1_H9_1_red.tif'

# %%
p1.shape
# Out:
# (1728, 1728, 3)

# %%
img = io.imread("/home/saurabh/Documents/dogscats/mitonui/1_H9_1_red.tif")

# %%
p1png = imsave("wohah.png", p1)

# %%
im1 = imread("/home/saurabh/Documents/dogscats/courses/deeplearninfileg1/nbs/wohah.png")

# %%
im1.shape
# Out:
# (1728, 1728, 3)

# %%
img.shape
# Out:
# (332, 500)

# %%
plt.show(io.imshow(img))
plt.show()

# %%
image = np.dstack([img, img, img])

# %%
image.shape
# Out:
# (332, 500, 3)

# %%
plt.show(io.imshow(image))
plt.show()

# %%
imsave("laflare.jpg", image)

# %%
laflare = imread("/home/saurabh/Documents/dogscats/sample/valid/cats/laflare.jpg")

# %%
laflare.shape
# Out:
# (332, 500, 3)

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
from PIL import Image
#import _pickle as cPickle
#import cPickle as pkl
import time
#import tensorflow as tf
#import tensorflow.examples.tutorials.mnist.input_data as input_data
import glob
from scipy.misc import imsave
#get_ipython().magic('matplotlib inline')
print ("Packages loaded")
# Out:
# Packages loaded

# %%
irpath = "C:/Users/Saurabh/Documents/resized/"
height = 240
width  = 360
resize_ratio = 4
nr_img = 0
fileList = glob.glob(dirpath + '*.jpg')
for i, file in enumerate(fileList):
    img = Image.open(file)
    array = np.array(img) 
    if array.shape[0] == height and array.shape[1] == width:
        nr_img = nr_img + 1
        rgb = array.reshape(1, height, width, 3)
        
        imglow = img.resize((int(width/resize_ratio) 
                ,int(height/resize_ratio)), Image.BICUBIC) # Reducing to 90*60 by bicubic
        #print("imglow")
        #print("THe width of imglow v1 is:",imglow.width)
        #plt.imshow(imglow)
        imglow = imglow.resize((width, height), Image.BICUBIC) # Resize to 360*240
        #print("img v2")
        #plt.imshow(imglow)
        #print("THe width of imglow v2 is:",imglow.width)
        
        rgblow = np.array(np.float32(imglow)/255.) # Converting to float 32
        rgblow = rgblow.reshape(1, height, width, 3) # Batch dimension (N * H * W * C)
        rgb = np.reshape(rgb, [1, -1])
        
        rgblow = np.reshape(rgblow, [1, -1])
        if nr_img == 1:
            data = rgb
            datalow = rgblow
        else:
            data = np.concatenate((data, rgb), axis=0)
            datalow = np.concatenate((datalow, rgblow), axis=0)
        
print ("nr_img is %d" % (nr_img))
print ("Shape of 'data' is %s" % (data.shape,))
print ("Shape of 'datalow' is %s" % (datalow.shape,))

# %%
irpath = "/home/saurabh/Documents/dogscats/mitonui/"

# %%
fileList = glob.glob(irpath + '*.png' )

# %%
for file in fileList:
    print file
# Out:
# /home/saurabh/Documents/dogscats/mitonui/1_H9_1_green.tif.png
# /home/saurabh/Documents/dogscats/mitonui/4_A4_2_yellow.tif.png
# /home/saurabh/Documents/dogscats/mitonui/4_A4_2_red.tif.png
# /home/saurabh/Documents/dogscats/mitonui/4_A4_1_green.tif.png
# /home/saurabh/Documents/dogscats/mitonui/1_H9_1_blue.tif.png
# /home/saurabh/Documents/dogscats/mitonui/4_A4_1_red.tif.png
# /home/saurabh/Documents/dogscats/mitonui/4_A4_1_blue.tif.png
# /home/saurabh/Documents/dogscats/mitonui/4_A4_2_blue.tif.png
# /home/saurabh/Documents/dogscats/mitonui/4_D5_1_green.tif.png
# /home/saurabh/Documents/dogscats/mitonui/1_H9_1_red.tif.png
# /home/saurabh/Documents/dogscats/mitonui/4_A4_1_yellow.tif.png
# /home/saurabh/Documents/dogscats/mitonui/1_H9_2_green.tif.png
# /home/saurabh/Documents/dogscats/mitonui/1_H9_2_blue.tif.png
# /home/saurabh/Documents/dogscats/mitonui/1_H9_2_yellow.tif.png
# /home/saurabh/Documents/dogscats/mitonui/1_H9_2_red.tif.png
# ...

# %%
for i,file in enumerate(fileList):
    img = imread(file)
    imsave(file + '.png', img)
    #print("DOne")

# %%
imgg = imread("C:/Users/Saurabh/Desktop/cyto2017/mito_nui/1_A8_1_blue.tif")

# %%
imgg.dtype
# Out:
# dtype('uint8')

# %%
a = imsave("aa.png", imgg)

# %%
aa = imread("aa.png")

# %%
aa.shape
# Out:
# (1728, 1728, 3)

# %%
aa.dtype
# Out:
# dtype('uint8')

# %%
im = imread("/home/saurabh/Documents/dogscats/mitonui/1_H9_2_blue.tif.png")

# %%
plt.imshow(imgg)
plt.show()
