# %%
import matplotlib.pyplot as plt
import numpy as np
import math
from PIL import Image
#import _pickle as cPickle
#import cPickle as pkl
import time
import tensorflow as tf
#import tensorflow.examples.tutorials.mnist.input_data as input_data
import glob
from scipy.misc import imsave, imread
get_ipython().magic('matplotlib inline')
print ("Packages loaded")

# %% [raw]
# dirpath = "C:/Users/Saurabh/Desktop/cyto2017/mito_nui/"

# %%
f = open("C:/Users/Saurabh/Desktop/mito_nui.txt")

# %%
a= list(f.read())

# %%
import csv

# %%
reader = csv.reader(open("C:/Users/Saurabh/Desktop/mito_nui.csv", "r"), delimiter=",")

# %%
for row in reader :
    print (row)

# %%
import os

# %%
files = os.listdir("C:/Users/Saurabh/Desktop/cyto2017/mito_nui/")
print(files)
a= (files[3])
print(a)
print(a[4])
print(a[1])
#print(str(1) + '_' + a[:-4])

# %%
a = "1001_G11_1_yellow.tif"

# %%
str.split(a)

# %%
dirpath = "C:/Users/Saurabh/Desktop/cyto2017/mito_nui/"
fileList = glob.glob(dirpath + '*.tif')

# %%
for i, file in enumerate(fileList):
    im = imread(file)
    print(file)
    imsave(str(i+1) + '.png', im)
    print(file, "is saved as", str(i+1) )
#print("Done")
    #rename(file,  )
    
    #for  # Loop in interval of 4 and save image as .png

# %%
from glob import glob
from os import rename
fileList = glob(dirpath + '*.tif')

for i,fname in enumerate(fileList):
    im = imread(fname)
    rename(fname, imsave(i.png, im) )

# %%
a = '1_G11_1_green.tif'
b = a[:-4].split('_' ,3 )
print(b)

# %%
c = b[0] + '_' + b[3] + '.tif'

# %%
print(c)

# %%
imtif = imread("C:/Users/Saurabh/Desktop/cyto2017/mito_nui/56_H5_1_green.tif")

# %%
im.dtype

# %%
impng = imread("C:/Users/Saurabh/Desktop/cyto2017/1.png")

# %%
impng.dtype

# %%
str = "C:/Users/Saurabh/Desktop/cyto2017/1_A8_1_blue.tif"

# %%
a = str[:-4]

# %%
print(a)

# %%
global str

# %%
a.replace("C:/Users/Saurabh/Desktop/cyto2017/", str(1))

# %%
import os
from os import rename
path = "C:/Users/Saurabh/Desktop/cyto2017/mito_nui/"
new_path = "C:/Users/Saurabh/Desktop/cyto2017/mito_nui/renamed/"

files = os.listdir("C:/Users/Saurabh/Desktop/cyto2017/mito_nui/")

print(files)
# Out:
# ['1000_blue.tif.gz', '1000_green.tif.gz', '1000_red.tif.gz', '1000_yellow.tif.gz', '1001_blue.tif.gz', '1001_green.tif.gz', '1001_red.tif.gz', '1001_yellow.tif.gz', '1002_blue.tif.gz', '1002_green.tif.gz', '1002_red.tif.gz', '1002_yellow.tif.gz', '1003_blue.tif.gz', '1003_green.tif.gz', '1003_red.tif.gz', '1003_yellow.tif.gz', '1004_blue.tif.gz', '1004_green.tif.gz', '1004_red.tif.gz', '1004_yellow.tif.gz', '1005_blue.tif.gz', '1005_green.tif.gz', '1005_red.tif.gz', '1005_yellow.tif.gz', '1006_blue.tif.gz', '1006_green.tif.gz', '1006_red.tif.gz', '1006_yellow.tif.gz', '1007_blue.tif.gz', '1007_green.tif.gz', '1007_red.tif.gz', '1007_yellow.tif.gz', '1008_blue.tif.gz', '1008_green.tif.gz', '1008_red.tif.gz', '1008_yellow.tif.gz', '1009_blue.tif.gz', '1009_green.tif.gz', '1009_red.tif.gz', '1009_yellow.tif.gz', '100_blue.tif.gz', '100_green.tif.gz', '100_red.tif.gz', '100_yellow.tif.gz', '1010_blue.tif.gz', '1010_green.tif.gz', '1010_red.tif.gz', '1010_yellow.tif.gz', '1011_blue.tif.gz
# ...

# %%
c
# Out:
# 1000_blue.ti_mito.tif.gz
# 1000_green.ti_mito.tif.gz
# 1000_red.ti_mito.tif.gz
# 1000_yellow.ti_mito.tif.gz
# 1001_blue.ti_mito.tif.gz
# 1001_green.ti_mito.tif.gz
# 1001_red.ti_mito.tif.gz
# 1001_yellow.ti_mito.tif.gz
# 1002_blue.ti_mito.tif.gz
# 1002_green.ti_mito.tif.gz
# 1002_red.ti_mito.tif.gz
# 1002_yellow.ti_mito.tif.gz
# 1003_blue.ti_mito.tif.gz
# 1003_green.ti_mito.tif.gz
# 1003_red.ti_mito.tif.gz
# 1003_yellow.ti_mito.tif.gz
# 1004_blue.ti_mito.tif.gz
# 1004_green.ti_mito.tif.gz
# 1004_red.ti_mito.tif.gz
# 1004_yellow.ti_mito.tif.gz
# 1005_blue.ti_mito.tif.gz
# 1005_green.ti_mito.tif.gz
# 1005_red.ti_mito.tif.gz
# 1005_yellow.ti_mito.tif.gz
# 1006_blue.ti_mito.tif.gz
# 1006_green.ti_mito.tif.gz
# 1006_red.ti_mito.tif.gz
# 1006_yellow.ti_mito.tif.gz
# 1007_blue.ti_mito.tif.gz
# 1007_green.ti_mito.tif.gz
# 1007_red.ti_mito.tif.gz
# 1007_yellow.ti_mito.tif.gz
# 1008_blue.ti_mito.tif.gz
# 1008_green.ti_mito.tif.gz
# 1008_red.ti_mito.tif.gz
# 1008_yellow.ti_mito.tif.gz
# ...

# %%
import csv

# %%
reader = csv.reader(open("C:/Users/Saurabh/Desktop/mito_nui.csv", "r"), delimiter=",")

# %%
labels = list(reader)

# %%
for l in labels:
    print( l[3])
# Out:
# Nucleoli
#
# Nucleoli
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Nucleoli
#
#
# Nucleoli
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Nucleoli
#
# Nucleoli
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Nucleoli
#
#
#
# Nucleoli
#
#
#
#
# Nucleoli
# Nucleoli
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Nucleoli
#
#
#
# Nucleoli
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Nucleoli
# Nucleoli
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
for l in labels:    
    #print(l[0])  # 
    for i in range(0,len(files)):
        a = []
        b = []
        a = files[i]
        #print(a)
        b = a[:-4].split('_', 3)
        #print(b[0])   # b[0] = 1001
        if b[0] == l[0]:
            print("success! for", b[0], "and",l[0]) #
            if l[3] == 'Nucleoli':
                print("STH")
                #print(b[0],"is",l[1])
                # In linux just move the file to nucleoli folder
                a = []
                b = []
                a = files[i]
                #print(a)   # orignal filename
                b = a[:-4].split('_', 3)
                #print(b[0])  # First digits before _
                c = b[0] +  '_' + b[1]  + "_" + str("BOTH") + '.tif' + '.gz' # '.gz'
                #print(c) #
                os.chdir("C:/Users/Saurabh/Desktop/cyto2017/mito_nui/")

                os.rename(a,c) #
                print(a,"a is renamed to",c) #
            elif l[1] == ' Nucleoli':
                #print(b[0],"is",l[1])
                # In linux just move the file to nucleoli folder
                a = []
                b = []
                a = files[i]
                #print(a)   # orignal filename
                b = a[:-4].split('_', 3)
                #print(b[0])  # First digits before _
                c = b[0] +  '_' + b[1]  + "_" + str("Nucleoli") + '.tif' + '.gz' # '.gz'
                #print(c) #
                os.chdir("C:/Users/Saurabh/Desktop/cyto2017/mito_nui/")

                os.rename(a,c) #
                #print(a,"a is renamed to",c) #
                
            elif l[1] == ' Mitochondria':
                #print(b[0],"is",l[1])
                # In linux just move the file to nucleoli folder
                #print(".") #
                #print(a) #
                a = []
                b = []
                a = files[i]
                #print(a)   # orignal filename
                b = a[:-4].split('_', 3)
                #print(b[0])  # First digits before _
                c = b[0] +  '_' + b[1]  + "_" + str("Mito") + '.tif' + '.gz' # '.gz'
                #print(c) #
                os.chdir("C:/Users/Saurabh/Desktop/cyto2017/mito_nui/")

                os.rename(a,c) #
                #print(a,"a is renamed to",c) #
            

                #os.rename(a,c) #
                #print(a,"a is renamed to",c) #
    #c = b[0] +  '_' + b[3]  + str(i) + '.tif'
    #print(c)
    #print("Renaming",  files[i], "to", c )
    #print(os.path.join(path, c))
    #filename = os.path.join(path, files[i])
    #rename(os.path.join(path, files[i]), os.path.join( new_path, c))
    #os.rename(filename, filename.replace(files[i],c)) # Rename the file
    #os.chdir("C:/Users/Saurabh/Desktop/cyto2017/mito_nui/")
    #os.rename(files[i], c)
# Out:
# success! for 1 and 1
# success! for 1 and 1
# success! for 1 and 1
# success! for 1 and 1
# success! for 2 and 2
# success! for 2 and 2
# success! for 2 and 2
# success! for 2 and 2
# success! for 3 and 3
# success! for 3 and 3
# success! for 3 and 3
# success! for 3 and 3
# success! for 4 and 4
# success! for 4 and 4
# success! for 4 and 4
# success! for 4 and 4
# success! for 5 and 5
# success! for 5 and 5
# success! for 5 and 5
# success! for 5 and 5
# success! for 6 and 6
# success! for 6 and 6
# success! for 6 and 6
# success! for 6 and 6
# success! for 7 and 7
# success! for 7 and 7
# success! for 7 and 7
# success! for 7 and 7
# success! for 8 and 8
# success! for 8 and 8
# success! for 8 and 8
# success! for 8 and 8
# success! for 9 and 9
# success! for 9 and 9
# success! for 9 and 9
# success! for 9 and 9
# success! for 10 and 10
# success! for 10 and 10
# success! for 10 and 10
# success! for 10 and 10
# success! for 11 and 11
# success! for 11 and 11
# ...

# %%
for l in labels:    
    #print(l[0])  
    for i in range(156,len(files)):
        a = []
        b = []
        a = files[i]
        #print(a)
        b = a[:-4].split('_', 3)
        #print(b[0])   # b[0] = 1001
        if b[0] == l[0]:
            #print("success! for", b[0], "and",l[0])
            if l[3] ==  'Nucleoli':
                #print(b[0],"is",l[1])
                # In linux just move the file to nucleoli folder
                #print("")
                #print(".")
                print(a)
                a = []
                b = []
                a = files[i]
                #print(a)   # orignal filename
                b = a[:-4].split('_', 3)
                #print(b[0])  # First digits before _
                c = b[0] +  '_' + b[1]  + "_" + str("BOTH") + '.tif' + '.gz' # '.gz'
                print(c)
                os.chdir("C:/Users/Saurabh/Desktop/cyto2017/mito_nui/")

                os.rename(a,c)
                print(a,"a is renamed to",c)
# Out:
# 94_blue.tif.gz
# 94_blue.ti_BOTH.tif.gz
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-75-3a8c90986e9f> in <module>()
#      26                 os.chdir("C:/Users/Saurabh/Desktop/cyto2017/mito_nui/")
#      27
# ---> 28                 os.rename(a,c)
#      29                 print(a,"a is renamed to",c)
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: '94_blue.tif.gz' -> '94_blue.ti_BOTH.tif.gz'
